# %% [markdown]
# <a href="https://colab.research.google.com/github/GOKUL-AI-tech/AI-/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers

# %%
from transformers import pipeline

# %%
generator = pipeline('text-generation', model='gpt2')
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
prompt = "the biography of thomas shelby"
output = generator(prompt, max_length=100)
print(output[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# the biography of thomas shelby)
#
# The author's wife, Ann, was a British actress, the only married woman in the country. She was married in 1858 and was a member of the Royal Family until 1878.
#
# The author's son, Thomas, has been a member of the Royal House of Lords since 1878.
#
# The author is survived by his wife Anne, daughter Mary, brother George, uncle Hugh, uncle William, and wife Elizabeth.
#
# His wife, Anne, died in November 2012.
#
# The author, who died in March 2013, passed away at the age of 81.
#
# ...
