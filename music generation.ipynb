# %% [markdown]
# <a href="https://colab.research.google.com/github/GOKUL-AI-tech/AI-/blob/main/music%20generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from transformers import MusicgenForConditionalGeneration, AutoProcessor
device = "cuda" if torch.cuda.is_available() else "cpu"
processor = AutoProcessor.from_pretrained("facebook/musicgen-small")
model = MusicgenForConditionalGeneration.from_pretrained("facebook/musicgen-small").to(device)
# Out:
# preprocessor_config.json:   0%|          | 0.00/275 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/2.36G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/224 [00:00<?, ?B/s]

# %%
prompt = ["lofi vhill beat with soft piano and pain"]
inputs = processor(
    text=prompt,
    padding=True,
    return_tensors="pt",
).to(device)

# %%
audio_value = model.generate(**inputs, max_new_tokens=512)
import scipy.io.wavfile as wavfile
wavfile.write("output.wav",rate=3200,data=audio_value[0, 0].cpu().numpy())
